# %%
import tensorflow as tf 
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/LALITH/Downloads/data2.csv')

# %%
df.tail()
# Out:
#         C      H     O2      GCV  Moisture  Efficiency    N2     S    Ash
# 42  75.77  14.31   5.37  7246.88       0.0   79.795456  0.12  0.02   8.49
# 43  74.57  10.97  10.69  7200.69       0.0   82.907868  0.16  0.01   2.65
# 44  19.61   2.83  49.56  2100.55       0.0   87.059905  0.74  0.03  14.66
# 45  48.00   6.40  37.60  3498.77       0.0   80.571395  2.60  0.40   5.00
# 46  47.80   6.00  38.00  3440.66       0.0   81.099211  3.40  0.30   4.50

# %%
a=[]
b=[]
c=[]
d=[]
e=[]
f=[]
g=[]
h=[]
j=[]

for i in range(0,47):
    a=a+ [df['C'][i]]
    b=b+ [df['H'][i]]
    c=c+ [df['O2'][i]]
    d=d+ [df['GCV'][i]]
    e=e+ [df['Moisture'][i]]
    f=f+ [df['Efficiency'][i]]
    g=g+ [df['N2'][i]]
    h=h+ [df['S'][i]]
    j=j+ [df['Ash'][i]]

# %%
a1=np.zeros(47)
b1=np.zeros(47)
c1=np.zeros(47)
d1=np.zeros(47)
e1=np.zeros(47)
f1=np.zeros(47)
g1=np.zeros(47)
h1=np.zeros(47)
j1=np.zeros(47)

for i in range(0,46):
    a1[i] = (a[i] - np.mean(a))/np.std(a)
    b1[i] = (b[i] - np.mean(b))/np.std(b)
    c1[i] = (c[i] - np.mean(c))/np.std(c)
    d1[i] = (d[i] - np.mean(d))/np.std(d)
    e1[i] = (e[i] - np.mean(e))/np.std(e)
    f1[i] = (f[i] - np.mean(f))/np.std(f)
    g1[i] = (g[i] - np.mean(g))/np.std(g)
    h1[i] = (h[i] - np.mean(h))/np.std(h)
    j1[i] = (j[i] - np.mean(j))/np.std(j)

# %%
df8 = pd.DataFrame(
{
    "c":a1,
    "h":b1,
    "o2":c1,
    "gcv":d1,
    "n2":g1,
    "s":h1,
    "Ash":j1
})

# %%
np.mean(f)
# Out:
# 79.26142510893618

# %%
np.std(f)
# Out:
# 6.11835707203802

# %%
df9 = pd.DataFrame({
    "eff":f
})

# %%
from sklearn.model_selection import train_test_split

# %%
x = df8.values

# %%
y = df9.values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
y_train.shape
# Out:
# (42, 1)

# %%
len(x_test)
# Out:
# 5

# %%
x_train = x_train.reshape(42, 7, 1)

# %%
import keras

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(32, input_shape=[7,1]))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(1))
optimizer = keras.optimizers.RMSprop(0.001)

model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_41 (LSTM)               (None, 32)                4352
# _________________________________________________________________
# dense_82 (Dense)             (None, 64)                2112
# _________________________________________________________________
# dense_83 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_84 (Dense)             (None, 1)                 33
# ...
# Total params: 8,577
# Trainable params: 8,577
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist=model.fit(
  x_train, y_train,
  epochs=2000)
# Out:
# Epoch 1/2000
# 42/42 [==============================] - 4s 85ms/step - loss: 6302.5993 - mean_absolute_error: 79.1400 - mean_squared_error: 6302.5993
# Epoch 2/2000
# 42/42 [==============================] - 0s 427us/step - loss: 6290.2875 - mean_absolute_error: 79.0617 - mean_squared_error: 6290.2875
# Epoch 3/2000
# 42/42 [==============================] - 0s 523us/step - loss: 6277.5920 - mean_absolute_error: 78.9812 - mean_squared_error: 6277.5920
# Epoch 4/2000
# 42/42 [==============================] - 0s 404us/step - loss: 6262.8352 - mean_absolute_error: 78.8875 - mean_squared_error: 6262.8352
# Epoch 5/2000
# 42/42 [==============================] - 0s 522us/step - loss: 6246.0861 - mean_absolute_error: 78.7809 - mean_squared_error: 6246.0861
# Epoch 6/2000
# 42/42 [==============================] - 0s 404us/step - loss: 6226.4632 - mean_absolute_error: 78.6562 - mean_squared_error: 6226.4632
# Epoch 7/2000
# ...

# %%
x_test = x_test.reshape(5, 7, 1)
x_test.shape
# Out:
# (5, 7, 1)

# %%
model.predict(x_test)
# Out:
# array([[73.750786],
#        [81.984604],
#        [76.83888 ],
#        [74.56318 ],
#        [73.62874 ]], dtype=float32)

# %%
y_test
# Out:
# array([[75.35696531],
#        [87.05990517],
#        [79.49732131],
#        [82.90786829],
#        [75.04771472]])
